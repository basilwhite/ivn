# %% [markdown]
# <a href="https://colab.research.google.com/github/basilwhite/ivn/blob/main/copy_of_ivn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas mlxtend openpyxl

# %%
import pandas as pd

# Load the Excel file from the URL
url = "https://basilwhite.com/ivn/ivntest.xlsx"
data = pd.read_excel(url)

# Display the first few rows of the dataframe
print("Data Preview:")
print(data.head())
# Out:
# Data Preview:
#   Enabling Source Enabling Component Enabling Component Description  \
# 0
# 1
# 2
# 3
# 4
#
#                                  Dependent Component  \
# 0  EO 14057 - Catalyzing Clean Energy Industries ...
# 1  FPI Program 10.55 - Supplemental Nutrition Ass...
# 2                       Goal 5 Technology Highlight
# 3  USDA FCSM Equitable Data Toolkit 2023 4.0: Met...
# 4  USDA FCSM Equitable Data Toolkit 2023 4.2: DUR...
#
#                      Dependent Component Description Dependent Source  \
# 0
# 1
# 2  Access to more accurate data will improve farm...
# 3  Developing a measure of persistent poverty or ...
# 4   The use of one data period, however, can be p...
#
#   Linkage mandated by what US Code or OMB policy? Enabling Component URL  \
# 0
# 1
# 2
# 3
# 4
#
#   Dependent Component URL Enabling Source Agency Dependent Source Agency  \
# 0
# 1
# 2
# 3
# 4
#
#   Column1 Notes and keywords  Keywords Tab Items Found     .1  .2
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Prepare the data for association rule learning
# Assuming the Excel file has columns 'Enabling Component' and 'Dependent Component'
basket = data.groupby(['Enabling Component', 'Dependent Component']).size().unstack().fillna(0)
basket = basket.applymap(lambda x: 1 if x > 0 else 0)

# Apply the Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(basket, min_support=0.1, use_colnames=True)

# Generate the association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Display the rules
print("Association Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# <ipython-input-7-e0c2c268edac>:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket = basket.applymap(lambda x: 1 if x > 0 else 0)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-e0c2c268edac> in <cell line: 12>()
#      10
#      11 # Generate the association rules
# ---> 12 rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
#      13
#      14 # Display the rules
#
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Prepare the data for association rule learning
# Assuming the Excel file has columns 'Enabling Component' and 'Dependent Component'
basket = data.groupby(['Enabling Component', 'Dependent Component']).size().unstack().fillna(0)
basket = basket.map(lambda x: x > 0)

# Apply the Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(basket, min_support=0.1, use_colnames=True)

# Generate the association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Display the rules
print("Association Rules:")
print(rules[['ante
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   File "<ipython-input-8-055ad8492204>", line 16
#     print(rules[['ante
#                  ^
# SyntaxError: unterminated string literal (detected at line 16)

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Prepare the data for association rule learning
# Assuming the Excel file has columns 'Enabling Component' and 'Dependent Component'
basket = data.groupby(['Enabling Component', 'Dependent Component']).size().unstack().fillna(0)
basket = basket.map(lambda x: x > 0)

# Apply the Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(basket, min_support=0.1, use_colnames=True)

# Generate the association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Display the rules
print("Association Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f8ef6b1ca615> in <cell line: 12>()
#      10
#      11 # Generate the association rules
# ---> 12 rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
#      13
#      14 # Display the rules
#
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/association_rules.py in association_rules(df, metric, min_threshold, support_only)
#      81     """
#      82     if not df.shape[0]:
# ---> 83         raise ValueError(
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Prepare the data for association rule learning
# Assuming the Excel file has columns 'Enabling Component' and 'Dependent Component'
basket = data.groupby(['Enabling Component', 'Dependent Component']).size().unstack().fillna(0)
basket = basket.map(lambda x: x > 0)

# Apply the Apriori algorithm to find frequent itemsets with a lower minimum support
frequent_itemsets = apriori(basket, min_support=0.01, use_colnames=True)

# Generate the association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Display the rules
print("Association Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Association Rules:
#                                           antecedents  \
# 0                 (Records maintained on individuals)
# 1       (ADMINISTRATION AND MISCELLANEOUS PROVISIONS)
# 2        (Confidentiality of certain medical records)
# 3                     (Confidential nature of claims)
# 4                     (Confidential nature of claims)
# 5   (Confidentiality of medical quality-assurance ...
# 6                 (Records maintained on individuals)
# 7                     (Confidential nature of claims)
# 8        (Confidentiality of certain medical records)
# 9   (Confidentiality of medical quality-assurance ...
# ...

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Load the Excel file from the URL
url = "https://basilwhite.com/ivn/ivntest.xlsx"
data = pd.read_excel(url)

# Display the first few rows of the dataframe
print("Data Preview:")
print(data.head())

# Prepare the data for association rule learning
# Assuming the Excel file has columns 'Enabling Component' and 'Dependent Component'
basket = data.groupby(['Enabling Component', 'Dependent Component']).size().unstack().fillna(0)
basket = basket.map(lambda x: x > 0)

# Apply the Apriori algorithm to find frequent itemsets with a lower minimum support
frequent_itemsets = apriori(basket, min_support=0.01, use_colnames=True)

# Generate the association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Display the rules
print("Association Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])

# Convert antecedents and consequents to strings for merging
rules['antecedents'] = rules['antecedents'].apply(lambda x: ', '.join(list(x)))
rules['consequents'] = rules['consequents'].apply(lambda x: ', '.join(list(x)))

# Merge the original data with the rules
merged_data = pd.merge(data, rules, how='left', left_on=['Enabling Component', 'Dependent Component'], right_on=['antecedents', 'consequents'])

# Save the combined data to a custom CSV file named 'ivn_inferences.csv'
merged_data.to_csv('ivn_inferences.csv', index=False)

# Display the saved CSV file path
print("Combined data with association rules has been saved to 'ivn_inferences.csv'")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Data Preview:
#   Enabling Source Enabling Component Enabling Component Description  \
# 0
# 1
# 2
# 3
# 4
#
#                                  Dependent Component  \
# 0  EO 14057 - Catalyzing Clean Energy Industries ...
# 1  FPI Program 10.55 - Supplemental Nutrition Ass...
# 2                       Goal 5 Technology Highlight
# 3  USDA FCSM Equitable Data Toolkit 2023 4.0: Met...
# 4  USDA FCSM Equitable Data Toolkit 2023 4.2: DUR...
#
#                      Dependent Component Description Dependent Source  \
# 0
# 1
# 2  Access to more accurate data will improve farm...
# 3  Developing a measure of persistent poverty or ...
# ...

# %%
import pandas as pd

# Load the IVN dataset from the URL
file_url = "https://basilwhite.com/ivn/ivntest.xlsx"

# Read the file from the URL
ivn_data = pd.read_excel(file_url)

# Add a column to mark rows as "Original" in the new column "OriginalvsInference"
ivn_data['OriginalvsInference'] = 'Original'

# Assume `inferred_data` is a DataFrame containing the inferred rows by the Python script
# For demonstration purposes, let's create an inferred data example
inferred_data = pd.DataFrame({
    'Component_1': ['Inferred component 1', 'Inferred component 2'],  # Example data
    'Component_2': ['Inferred component 3', 'Inferred component 4'],  # Example data
    'Description': ['Inference description 1', 'Inference description 2'],  # Example data
    'antecedents': [None, None],  # Example inferred values
    'consequents': [None, None],  # Example inferred values
    'antecedent support': [None, None],  # Example inferred values
    'consequent support': [None, None],  # Example inferred values
    'support': [None, None],  # Example inferred values
    'confidence': [None, None],  # Example inferred values
    'lift': [None, None],  # Example inferred values
    'leverage': [None, None],  # Example inferred values
    'conviction': [None, None],  # Example inferred values
    'zhangs_metric': [None, None],  # Example inferred values
})

# Add a column to mark rows as "Inference" in the new column "OriginalvsInference"
inferred_data['OriginalvsInference'] = 'Inference'

# Combine the original data with the inferred data, keeping all columns
combined_data = pd.concat([ivn_data, inferred_data], ignore_index=True)

# Save the combined data as a new CSV file
combined_data.to_csv('ivn_inferences.csv', index=False)

# Display a few rows for confirmation
combined_data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   Enabling Source Enabling Component Enabling Component Description  \
# 0
# 1
# 2
# 3
# 4
#
#                                  Dependent Component  \
# 0  EO 14057 - Catalyzing Clean Energy Industries ...
# 1  FPI Program 10.55 - Supplemental Nutrition Ass...
# 2                       Goal 5 Technology Highlight
# 3  USDA FCSM Equitable Data Toolkit 2023 4.0: Met...
# 4  USDA FCSM Equitable Data Toolkit 2023 4.2: DUR...
#
#                      Dependent Component Description Dependent Source  \
# 0
# 1
# 2  Access to more accurate data will improve farm...
# 3  Developing a measure of persistent poverty or ...
# ...

# %%
import pandas as pd

# Load the IVN dataset from the URL
file_url = "https://basilwhite.com/ivn/ivntest.xlsx"
ivn_data = pd.read_excel(file_url)

# Add a column to mark rows as "Original"
ivn_data['Source'] = 'Original'

# Generate new inferred pairs based on the existing data
# Swap 'Enabling Component' and 'Dependent Component' to create inferred pairs
inferred_data = ivn_data[['Dependent Component', 'Enabling Component']].copy()
inferred_data.columns = ['Enabling Component', 'Dependent Component']
inferred_data['Source'] = 'Inferred'

# Concatenate the original and inferred DataFrames
combined_data = pd.concat([ivn_data, inferred_data], ignore_index=True, sort=False)

# Save the combined DataFrame to a CSV file
combined_data.to_csv('ivn_inferences.csv', index=False)

print("ivn_inferences.csv has been created successfully.")
# Out:
# ivn_inferences.csv has been created successfully.

# %%
import pandas as pd

# Load the original inferred data
inferred_file = 'ivn_inferences.csv'  # File generated by the script
corrected_file = 'ivn_corrected.csv'  # Corrected by the user

# Read both the inferred data and the corrected data
inferred_data = ivn_inferences.csv
corrected_data = ivn_corrected.csv

# Filter only the inferred rows from both datasets
inferred_rows = inferred_data[inferred_data['OriginalvsInference'] == 'Inference']
corrected_rows = corrected_data[corrected_data['OriginalvsInference'] == 'Inference']

# Identify corrections by comparing inferred rows to corrected rows
# You can compare the rows based on specific columns, such as 'Component_1', 'Component_2', etc.
corrections = corrected_rows.compare(inferred_rows, keep_shape=True, keep_equal=False)

# Display corrections for review
print("Corrections made by the user:")
print(corrections)

# Update your inference logic here based on the corrections
# Example: If certain patterns in the 'Component_1' column were incorrect, you can adjust those patterns.
# This part would depend on the logic your script used to generate the inferences.

# Save the corrected rows as a "learning dataset" for future reference
corrections.to_csv('learning_dataset.csv', index=False)

# Next time the script runs, you can load 'learning_dataset.csv' and apply corrections to future inferences
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5132ba28b6ea> in <cell line: 8>()
#       6
#       7 # Read both the inferred data and the corrected data
# ----> 8 inferred_data = ivn_inferences.csv
#       9 corrected_data = ivn_corrected.csv
#      10
#
# NameError: name 'ivn_inferences' is not defined

# %%
# Load the learning dataset
learning_data = pd.read_csv('learning_dataset.csv')

# Use this data to adjust future inferences
# For example, you could check if a new inference matches any correction pattern and apply the correction
for index, row in inferred_data.iterrows():
    # Example: if a specific correction pattern was found in 'Component_1', apply that to new inferences
    if row['Component_1'] in learning_data['Component_1'].values:
        inferred_data.loc[index, 'Component_1'] = learning_data.loc[learning_data['Component_1'] == row['Component_1'], 'Component_1'].values[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-124f58103181> in <cell line: 2>()
#       1 # Load the learning dataset
# ----> 2 learning_data = pd.read_csv('learning_dataset.csv')
#       3
#       4 # Use this data to adjust future inferences
#       5 # For example, you could check if a new inference matches any correction pattern and apply the correction
#
# NameError: name 'pd' is not defined
